# %%
def gradient_descent(x0, y0, grad_f, alpha, num_it):
    x, y= x0, y0
    for i in range(num_it):
        grad_x, grad_y = grad_f(x,y)
        x= x - alpha*grad_x
        y = y- alpha*grad_y
    return x, y 

def f(x, y):
    return x**2, y**2

def grad_f(x, y):
    return 2*x, 2*y

alpha = 0.1
num_it = 100
x0, y0 = 1, 1

x_f, y_f = gradient_descent(x0, y0, grad_f, alpha, num_it)

print(f"final point: ({x_f:}, {y_f})")
print(f"minimum point: {f(x_f, y_f)}")
# Out:
# final point: (2.0370359763344877e-10, 2.0370359763344877e-10)
# minimum point: (4.1495155688809995e-20, 4.1495155688809995e-20)

# %%
def fun_1(x,y):
    return x**2 + y**2

def grad_f_1(x,y):
    grad_x = 2*x
    grad_y = 2*y
    return grad_x, grad_y



test = [((0.1, 0.1), 0.1, 10), ((-1, 1), 0.01, 100)]

for i in range(len(test)):
    initial_pt, alpha, num_it = test[i]
    x_f, y_f = gradient_descent(*initial_pt, grad_f_1, alpha, num_it)
    print(f"test case {i + 1}:")
    print(f"Initial point : {initial_pt}")
    print(f"final point:({x_f}, {y_f})")
    print(f"Min Value{fun_1(x_f, y_f)}")
# Out:
# test case 1:
# Initial point : (0.1, 0.1)
# final point:(0.010737418240000003, 0.010737418240000003)
# Min Value0.00023058430092136951
# test case 2:
# Initial point : (-1, 1)
# final point:(-0.13261955589475316, 0.13261955589475316)
# Min Value0.03517589321144311

# %%
import numpy as np
def fun_2(x, y):
    return 1 - np.exp(-x**2 - (y-2)**2) - 2*np.exp(-x**2 - (y+2)**2)

x0, y0 = 0,1
alpha = 0.1
num_it=1000

def grad_f_2(x, y):
    grad_x = 2*x*np.exp(-x**2 - (y-2)**2) + 4*x*np.exp(-x**2 - (y+2)**2)
    grad_y = 2*(y-2)*np.exp(-x**2 - (y-2)**2) + 4*(y+2)*np.exp(-x**2 - (y+2)**2)
    return grad_x, grad_y

def gradient_descent(x0, y0, grad_f, alpha, num_it):
    x, y= x0, y0
    for i in range(num_it):
        grad_x, grad_y = grad_f(x,y)
        x= x - alpha*grad_x
        y = y- alpha*grad_y
    return x, y 

def f(x, y):
    return x**2, y**2

def grad_f(x, y):
    return 2*x, 2*y

alpha = 0.1
num_it = 100
x0, y0 = 1, 1

x_f, y_f = gradient_descent(x0, y0, grad_f, alpha, num_it)

print(f"final point: ({x_f:}, {y_f})")
print(f"minimum point: {f(x_f, y_f)}")

test = [((0.1, 0.1), 0.1, 10), ((-1, 1), 0.01, 100)]

for i in range(len(test)):
    initial_pt, alpha, num_it = test[i]
    x_f, y_f = gradient_descent(*initial_pt, grad_f_1, alpha, num_it)
    print(f"test case {i + 1}:")
    print(f"Initial point : {initial_pt}")
    print(f"final point:({x_f}, {y_f})")
    print(f"Min Value{fun_1(x_f, y_f)}")
# Out:
# final point: (2.0370359763344877e-10, 2.0370359763344877e-10)
# minimum point: (4.1495155688809995e-20, 4.1495155688809995e-20)
# test case 1:
# Initial point : (0.1, 0.1)
# final point:(0.010737418240000003, 0.010737418240000003)
# Min Value0.00023058430092136951
# test case 2:
# Initial point : (-1, 1)
# final point:(-0.13261955589475316, 0.13261955589475316)
# Min Value0.03517589321144311

# %%
import numpy as np
from mpl_toolkits import mplot3d #for 3D plots
import matplotlib.pyplot as plt 

def fun2(x, y):
    return 1 - np.exp(-x**2 - (y-2)**2) - 2*np.exp(-x**2 - (y+2)**2) 
    
X = np.linspace(-5, 5, 100)
Y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(X, Y)
z = fun2(x, y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax_set_zlabel('f(x, y)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      16 ax.set_xlabel('x')
#      17 ax.set_ylabel('y')
# ---> 18 ax_set_zlabel('f(x, y)')
#      19 plt.show()
#
# NameError: name 'ax_set_zlabel' is not defined

# %%
def fun2(x, y):
    return 1 - np.exp(-x**2 - (y-2)**2) - 2*np.exp(-x**2 - (y+2)**2) 
    
def grad_f_2(x, y):
    grad_x = 2*x*np.exp(-x**2 - (y-2)**2) + 4*x*np.exp(-x**2 - (y+2)**2)
    grad_y = 2*(y-2)*np.exp(-x**2 - (y-2)**2) + 4*(y+2)*np.exp(-x**2 - (y+2)**2)
    return grad_x, grad_y

X = np.linspace(-5, 5, 100)
Y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(X, Y)
gx, gy= grad_f_2(x, y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax_set_zlabel('f(x, y)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 19
#      17 ax.set_xlabel('x')
#      18 ax.set_ylabel('y')
# ---> 19 ax_set_zlabel('f(x, y)')
#      20 plt.show()
#
# NameError: name 'ax_set_zlabel' is not defined
