# %%
import matplotlib.pyplot as plt
import random

# Vertices of an equilateral triangle
vertices = [(0, 0), (1, 0), (0.5, 0.866)]

# Function to check whether a point (x, y) lies inside a triangle
def isInside(x1, y1, x2, y2, x3, y3, x, y):
    def area(x1, y1, x2, y2, x3, y3):
        return abs((x1*(y2 - y3) + x2*(y3 - y1) + x3*(y1 - y2)) / 2.0)

    A = area(x1, y1, x2, y2, x3, y3)
    A1 = area(x, y, x2, y2, x3, y3)
    A2 = area(x1, y1, x, y, x3, y3)
    A3 = area(x1, y1, x2, y2, x, y)
    return A == A1 + A2 + A3

# Prompting the user for a seed point
while True:
    try:
        seed_x = float(input("Enter the x-coordinate of the seed point: "))
        seed_y = float(input("Enter the y-coordinate of the seed point: "))
        if isInside(0, 0, 1, 0, 0.5, 0.866, seed_x, seed_y):
            print("Valid seed point entered.")
            break
        else:
            print("The point is not inside the triangle. Please try again.")
    except ValueError:
        print("Invalid input. Please enter numerical values.")

# This is your starting point
seed = (seed_x, seed_y)

# Initialize a list where you will store your points (x_t, y_t), starting with your seed
points = [seed]

# Prompting the user for the number of steps
while True:
    try:
        num_steps = int(input("Enter the number of steps: "))
        if num_steps > 0:
            print(f"Number of steps set to {num_steps}.")
            break
        else:
            print("Please enter a positive integer.")
    except ValueError:
        print("Invalid input. Please enter a positive integer.")

# Chaos Game algorithm implementation
for i in range(num_steps):
    # Choose a random vertex
    next_vertex = random.choice(vertices)

    # Create the next point by moving from the last point to the midpoint
    next_point = (
        (points[-1][0] + next_vertex[0]) / 2,
        (points[-1][1] + next_vertex[1]) / 2
    )

    # Add the new point to the list of points
    points.append(next_point)

# Function to plot the solution set
def plot_solution(points):
    plt.scatter([p[0] for p in points], [p[1] for p in points], s=0.1)
    plt.show()

# Plot your points
plot_solution(points)
# Out:
# Enter the x-coordinate of the seed point:  1202
# Enter the y-coordinate of the seed point:  122
# The point is not inside the triangle. Please try again.
# Enter the x-coordinate of the seed point:  0.5
# Enter the y-coordinate of the seed point:  0.3
# The point is not inside the triangle. Please try again.
# Enter the x-coordinate of the seed point:  2
# Enter the y-coordinate of the seed point:  0
# The point is not inside the triangle. Please try again.
# Enter the x-coordinate of the seed point:  0.5
# Enter the y-coordinate of the seed point:  0.5
# Valid seed point entered.
# Enter the number of steps:  1000
# Number of steps set to 1000.

# %%
import matplotlib.pyplot as plt
import random

# Vertices of an equilateral triangle
vertices = [(0, 0), (1, 0), (0.5, 0.866)]

# Function to check whether a point (x, y) lies inside a triangle
def isInside(x1, y1, x2, y2, x3, y3, x, y):
    def area(x1, y1, x2, y2, x3, y3):
        return abs((x1*(y2 - y3) + x2*(y3 - y1) + x3*(y1 - y2)) / 2.0)

    A = area(x1, y1, x2, y2, x3, y3)
    A1 = area(x, y, x2, y2, x3, y3)
    A2 = area(x1, y1, x, y, x3, y3)
    A3 = area(x1, y1, x2, y2, x, y)
    return A == A1 + A2 + A3

# Prompting the user for a seed point
while True:
    try:
        seed_x = float(input("Enter the x-coordinate of the seed point: "))
        seed_y = float(input("Enter the y-coordinate of the seed point: "))
        if isInside(0, 0, 1, 0, 0.5, 0.866, seed_x, seed_y):
            print("Valid seed point entered.")
            break
        else:
            print("The point is not inside the triangle. Please try again.")
    except ValueError:
        print("Invalid input. Please enter numerical values.")

# This is your starting point
seed = (seed_x, seed_y)

# Initialize a list where you will store your points (x_t, y_t), starting with your seed
points = [seed]

# Prompting the user for the number of steps
while True:
    try:
        num_steps = int(input("Enter the number of steps: "))
        if num_steps > 0:
            print(f"Number of steps set to {num_steps}.")
            break
        else:
            print("Please enter a positive integer.")
    except ValueError:
        print("Invalid input. Please enter a positive integer.")

# Chaos Game algorithm implementation
for i in range(num_steps):
    # Choose a random vertex
    next_vertex = random.choice(vertices)

    # Create the next point by moving from the last point to the midpoint
    next_point = (
        (points[-1][0] + next_vertex[0]) / 2,
        (points[-1][1] + next_vertex[1]) / 2
    )

    # Add the new point to the list of points
    points.append(next_point)

# Function to plot the solution set
def plot_solution(points):
    plt.scatter([p[0] for p in points], [p[1] for p in points], s=0.1)
    plt.show()

# Plot your points
plot_solution(points)
# Out:
# Enter the x-coordinate of the seed point:  0.1
# Enter the y-coordinate of the seed point:  0.1
# Valid seed point entered.
# Enter the number of steps:  90000
# Number of steps set to 90000.

# %%
import matplotlib.pyplot as plt
import random

# Vertices of an equilateral triangle
vertices = [(0, 0), (1, 0), (0.5, 0.866)]

# Function to check whether a point (x, y) lies inside a triangle
def isInside(x1, y1, x2, y2, x3, y3, x, y):
    def area(x1, y1, x2, y2, x3, y3):
        return abs((x1*(y2 - y3) + x2*(y3 - y1) + x3*(y1 - y2)) / 2.0)

    A = area(x1, y1, x2, y2, x3, y3)
    A1 = area(x, y, x2, y2, x3, y3)
    A2 = area(x1, y1, x, y, x3, y3)
    A3 = area(x1, y1, x2, y2, x, y)
    return A == A1 + A2 + A3

# Prompting the user for a seed point
while True:
    try:
        seed_x = float(input("Enter the x-coordinate of the seed point: "))
        seed_y = float(input("Enter the y-coordinate of the seed point: "))
        if isInside(0, 0, 1, 0, 0.5, 0.866, seed_x, seed_y):
            print("Valid seed point entered.")
            break
        else:
            print("The point is not inside the triangle. Please try again.")
    except ValueError:
        print("Invalid input. Please enter numerical values.")

# This is your starting point
seed = (seed_x, seed_y)

# Initialize a list where you will store your points (x_t, y_t), starting with your seed
points = [seed]

# Prompting the user for the number of steps
while True:
    try:
        num_steps = int(input("Enter the number of steps: "))
        if num_steps > 0:
            print(f"Number of steps set to {num_steps}.")
            break
        else:
            print("Please enter a positive integer.")
    except ValueError:
        print("Invalid input. Please enter a positive integer.")

# Chaos Game algorithm implementation
for i in range(num_steps):
    # Choose a random vertex
    next_vertex = random.choice(vertices)

    # Create the next point by moving from the last point to the midpoint
    next_point = (
        (points[-1][0] + next_vertex[0]) / 2,
        (points[-1][1] + next_vertex[1]) / 2
    )

    # Add the new point to the list of points
    points.append(next_point)

# Function to plot the solution set
def plot_solution(points):
    plt.scatter([p[0] for p in points], [p[1] for p in points], s=0.1)
    plt.show()

# Plot your points
plot_solution(points)
# Out:
# Enter the x-coordinate of the seed point:  0.1
# Enter the y-coordinate of the seed point:  0.1
# Valid seed point entered.
# Enter the number of steps:  300
# Number of steps set to 300.
